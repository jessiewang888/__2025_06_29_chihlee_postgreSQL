# %% [markdown]
# ### 這是python基礎課程
# - python基本資料型別

# %%
print("Hello! Python!")
print("以下是python的基本資料類型(int,float,str,bool)")
15 #整數,(int)
15.0 #浮點數,(float)
"15.0" #字串,(str)
'15.0' #字串(str)
True #布林值,(bool)
False #布林值,(bool)
# Out:
# Hello! Python!
# 以下是python的基本資料類型(int,float,str,bool)
# False

# %%
print("SELECT \"stationCode\",\"stationName\",\"stationAddraTW\"\nFROM\"台鐵車站資訊\"\nWHERE\"stationAddrTW\" LIKE \'%基隆市%\';")
# Out:
# SELECT "stationCode","stationName","stationAddraTW"
# FROM"台鐵車站資訊"
# WHERE"stationAddrTW" LIKE '%基隆市%';
